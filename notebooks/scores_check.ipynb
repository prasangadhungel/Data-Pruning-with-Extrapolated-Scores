# %%
import numpy as np

# read /nfs/homedirs/dhp/unsupervised-data-pruning/scores/prune/tdds/score_win10_ep10.npy
moving_averages_sum_sort = np.load('/nfs/homedirs/dhp/unsupervised-data-pruning/scores/prune/tdds/score_win10_ep10.npy')
data_mask = np.load('/nfs/homedirs/dhp/unsupervised-data-pruning/scores/prune/tdds/data_mask_win10_ep10.npy')

# %%
moving_averages_sum_sort[-20:]
# Out:
# array([11.377414, 11.422513, 11.47147 , 11.486483, 11.495755, 11.574719,
#        11.684839, 11.716816, 11.773737, 11.871382, 11.873825, 12.008427,
#        12.044849, 12.145355, 12.810549, 12.912394, 13.14628 , 13.153081,
#        15.17218 , 15.259644], dtype=float32)

# %%
data_mask[-20:]
# Out:
# array([19761,  6170, 18178, 46725, 11886, 21243, 43427, 21065, 13623,
#        27199, 38574, 47000, 43031, 32478, 48081, 22418, 19932, 40677,
#         3518, 18609])

# %%
score_dict = dict(zip(data_mask, moving_averages_sum_sort))

# %%
score_dict[0]
# Out:
# 0.74741614
